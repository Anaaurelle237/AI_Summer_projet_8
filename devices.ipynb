# %%
import numpy as np
import pandas as  pd 
import random
from faker import Faker
from uuid import uuid4
from tqdm import tqdm

faker= Faker()

# %%
3#. devices
#Informations sur les appareils utilisés pour les transactions.
#● device_id (VARCHAR) : Identifiant unique de l'appareil.
#● device_type (VARCHAR) : Type de l'appareil (mobile, tablette).
#● os (VARCHAR) : Système d'exploitation de l'appareil.
#● manufacturer (VARCHAR) : Fabricant de l'appareil.
#● model (VARCHAR) : Modèle de l'appareil.
#● last_used (DATETIME) : Dernière utilisation de l'appareil.

# %%
#creation de id

def create_id():
    return str(uuid4())

#creation des types d'appareils
def generate_device_type():
    return random.choice(['mobile', 'tablette'])

#creation des os

def generate_os():
    return random.choice(['android', 'ios', 'mac', 'windows', 'linux'])

#creation des fabricants
manufacturer_and_model={
                        'dell':['XPS 13', 'INSPIRON 15', 'LATITUDE 7410', 'PRECISION 5550'],
                        'HP': ['spectre x360', 'envy 13', 'pavillon 15', 'OMEN 15'],
                        'LG': ['spectre x3670', 'envy45','Gram 17', 'Wing 5G', ' NanoCell TV'],
                        'SONY':['Xperia 1 III', 'Xperia 5 II', 'Bravia OLDE', 'VAIO SX14'],
                        'Apple':['iphone 13', 'ipad pro', 'iphone Xr'],
                        'Sharp':['Aquos R6', 'aquos sense 5g', ' dynabook v8']
                        }
#def generate_manufacturer():
    #return random.choices(['dell', 'hp', 'lg', 'sony', 'apple', 'sharp', 'lenovo', 'acer', 'tecno','itel', 'huawei', 'samsung', 'google'])

#creation des modeles

def generate_model(type):
    return random.choice(manufacturer_and_model[type])

# %%
#creation de la table devices

def create_devices_table(lenght= 100):

    devices= pd.DataFrame()

    # les listes
    devices_id_list=[]
    devices_type_list=[]
    devices_manufacturer_list=[]
    devices_model_list=[]
    devices_last_used_list=[]
    devices_os_list=[]

    #generer les valeurs
    for i in tqdm(range(lenght)):
        devices_id=create_id()
        devices_type= generate_device_type()
        devices_last_used= faker.date_time_between(start_date= '-5y', end_date='now')
        devices_os= generate_os()
        devices_manufacturer= random.choice(list(manufacturer_and_model.keys()))
        devices_model= generate_model(devices_manufacturer)

        #ajout dans les listes
        devices_id_list.append(devices_id)
        devices_type_list.append(devices_type)
        devices_model_list.append( devices_model)
        devices_manufacturer_list.append( devices_manufacturer)
        devices_last_used_list.append(devices_last_used)
        devices_os_list.append(devices_os)
        
     #assigner aux colonnes de la table devices
    devices['device_id']= devices_id_list
    devices['device_type']= devices_type_list
    devices['os']= devices_os_list
    devices['manufacturer']= devices_manufacturer_list
    devices['model']= devices_model_list
    devices['last_used']= devices_last_used_list

    return devices

devices= create_devices_table()
devices
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 5885.67it/s]
#                                device_id device_type       os manufacturer  \
# 0   9f39dad3-1ff5-42a0-9dfc-154d68cf6ae6    tablette    Linux        Sharp
# 1   f82d4744-8f4d-41c8-8669-085987c380e0      mobile  Windows           HP
# 2   170e2bdf-6c1b-4d17-9757-f5892b5a88d7      mobile    Linux       Google
# 3   7964f185-6cb2-4cf7-b36c-20c5d69c3e67      mobile      iOS        Sharp
# 4   31606f8b-f5ba-4f67-b1ca-a49576fcb6a6      mobile  Android       Huawei
# ..                                   ...         ...      ...          ...
# 95  52f509fc-3953-45e6-a810-0e71d0823f3e    tablette    Linux           LG
# 96  fd5feecb-edfd-4939-9b16-355ea1d791bc    tablette    Linux         Sony
# 97  ddfbc6e6-f65f-44d5-a929-74ecc32e6e8d    tablette    Linux        Sharp
# 98  177049b5-5cef-44d6-b9c4-1681dd767d56      mobile  Windows       Lenovo
# 99  122f6355-e799-4c5b-924e-f42e318a1b9d    tablette  Android         Dell
#
#                  model           last_used
# 0          Dynabook V8 2023-10-04 17:48:45
# 1          Pavilion 15 2021-06-26 10:00:28
# 2            Pixelbook 2022-01-19 17:08:09
# 3             Aquos R6 2019-11-24 19:43:04
# 4              Mate 30 2020-08-10 04:23:01
# ..                 ...                 ...
# 95           V60 ThinQ 2020-03-15 01:32:55
# 96         Bravia OLED 2022-05-14 10:46:41
# 97         Dynabook V8 2022-09-04 03:22:39
# 98  ThinkPad X1 Carbon 2022-07-02 08:38:59
# 99         Inspiron 15 2021-12-18 14:41:33
#
# [100 rows x 6 columns]
