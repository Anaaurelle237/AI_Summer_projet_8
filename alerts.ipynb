# %%
import pandas as pd
from faker import Faker
from uuid import uuid4
from tqdm import tqdm
import random

faker = Faker()

# %%
# Fonction pour générer un identifiant unique
def create_id():
    return str(uuid4())

# Fonction pour générer une date et heure aléatoire
def generate_alert_date():
    return faker.date_time_between(start_date='-5y', end_date='now')

# Fonction pour générer un type d'alerte aléatoire
def generate_alert_type():
    return random.choice(['suspicious activity', 'large transaction'])

# Fonction pour générer un statut d'alerte aléatoire
def generate_alert_status():
    return random.choice(['open', 'closed'])

# Fonction pour générer une description d'alerte aléatoire
def generate_description():
    return faker.text(max_nb_chars=250)

# %%
# Fonction pour créer une table d'alertes
def create_alerts_table(length=100):

    alerts = pd.DataFrame()

    # Les listes
    alert_id_list = []
    transaction_id_list = []
    alert_date_list = []
    alert_type_list = []
    alert_status_list = []
    description_list = []

    # Générer les valeurs
    for i in tqdm(range(length)):
        alert_id = create_id()
        transaction_id = create_id()  # Remplacer par un identifiant de transaction réel si disponible
        alert_date = generate_alert_date()
        alert_type = generate_alert_type()
        alert_status = generate_alert_status()
        description = generate_description()

        # Ajouter dans les listes
        alert_id_list.append(alert_id)
        transaction_id_list.append(transaction_id)
        alert_date_list.append(alert_date)
        alert_type_list.append(alert_type)
        alert_status_list.append(alert_status)
        description_list.append(description)
    
    # Assigner aux colonnes de la table alerts (en dehors de la boucle)
    alerts['alert_id'] = alert_id_list
    alerts['transaction_id'] = transaction_id_list
    alerts['alert_date'] = alert_date_list
    alerts['alert_type'] = alert_type_list
    alerts['alert_status'] = alert_status_list
    alerts['description'] = description_list

    return alerts

# Créer une table d'alertes
alerts = create_alerts_table()

# Afficher les premières lignes de la table alerts
alerts
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 1725.22it/s]
#                                 alert_id  \
# 0   18d83748-dfa3-47e7-85fa-428e0762cd13
# 1   ad4e18ad-04a4-4ee6-b59c-6657fa05cac1
# 2   9eda0dd7-597f-45c3-821e-cf0fa132f7bb
# 3   dce8dc1b-b60a-4ec9-9e08-4d06a43822be
# 4   ba9a5120-77cc-4b0d-816c-ab4abd58bf67
# ..                                   ...
# 95  b6c48806-f119-4771-8859-fd9faa1eb0d6
# 96  c43ff4e0-6a7f-4283-a936-a741c6ffffbc
# 97  8e5a3aa0-bab8-455a-915a-6b16362bc90b
# 98  7ee7cdbf-5f19-4d14-87a8-0654fbc53feb
# 99  6b497577-3f0d-48e4-bd27-04b0edaccb8e
#
#                           transaction_id          alert_date  \
# 0   3d9e7a68-5f78-4f49-9b3b-60d187ee4b03 2023-10-02 12:42:40
# 1   21114a0b-c7ba-4f19-bee6-1879cb9d498f 2021-03-18 13:48:11
# 2   c3f5277c-3b73-4005-8d87-a1b98ef18fd9 2021-12-31 01:22:52
# 3   9bdcfbdc-7665-46a7-94e8-92f84b039e1f 2019-09-16 15:56:04
# 4   c97f5e4e-8d82-4d84-ba4c-210d1eb18fa6 2020-07-07 12:33:46
# ..                                   ...                 ...
# 95  9805db74-16cf-451e-9392-e9101dfaa0e8 2023-04-14 11:39:01
# 96  56d4e719-3404-4181-8f90-f910515f06ff 2019-09-02 01:39:31
# 97  5e25fd83-3751-4eb2-a7c3-87a19a531d4e 2023-10-17 22:55:16
# 98  83ccbf31-340d-40df-8adc-5ff5d5335576 2021-01-29 15:50:57
# 99  020ea9e2-808a-4acf-9440-4ba37d2959fc 2022-01-13 04:21:13
#
#              alert_type alert_status  \
# 0   suspicious activity         open
# 1     large transaction         open
# 2   suspicious activity       closed
# 3   suspicious activity       closed
# 4     large transaction       closed
# ..                  ...          ...
# 95    large transaction       closed
# 96  suspicious activity       closed
# 97    large transaction         open
# 98  suspicious activity       closed
# 99    large transaction         open
#
#                                           description
# 0   Term company reality special. Direction necess...
# 1   Bad oil cause wide seem. Style market field.\n...
# 2   Television travel goal pattern back offer reac...
# 3   Movie compare have nothing trouble campaign.\n...
# 4   Include edge recently method Mrs give. Soon pe...
# ..                                                ...
# 95  Thus manager break wish military into behind i...
# 96  Strong four avoid agree bad. Simple energy env...
# 97  Brother eat something system. This official no...
# 98  Well dog sit. Yourself physical ball. Choose h...
# 99  Compare often up bar. Discussion brother conta...
#
# [100 rows x 6 columns]
