# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
import sqlite3

# %matplotlib inline

# %%
# Create a connection to the SQLite database
conn = sqlite3.connect('../Data/db/fraude_detection_warehouse.db')

# %%
transactions = pd.read_sql('SELECT * FROM transactions', conn)
transactions.head()
# Out:
#                      transaction_id                       customer_id  \
# 0  c97933246a82467a9cfb40ab1d612897  bfac7b9b0f9c4c2b92124cf5f9bac2c2
# 1  93fbfd13f9b34e0d9820b8731340aa40  e7506952844a4d38be9379d7580e4c25
# 2  2ae38ab84eec4dad879cc457ffe0c954  913098ce3c834dbbb199ebdf11ac1955
# 3  fa94fac99017496b9c8139c474a9b1da  42b6a8b5a41845ceaa50554faaa9610b
# 4  8bbb805c101b420793a3b51b22766613  5d5cc9db27534a6aaa5434114c6b6c3a
#
#                               device_id transaction_type transaction_date  \
# 0  c2e3ea31-d1a5-4d65-a9f8-8b3b733a33b4        transfert       2005-08-23
# 1  2beb8b14-8655-4b71-a925-ef4ba64b2295          retrait       2005-03-31
# 2  ef66fa7d-0f58-43dd-aa29-aa9af742a86c        transfert       2011-12-17
# 3  d676bb76-3798-49d9-83c6-a7d8d20c4302            depôt       2014-03-10
# 4  e8a74deb-98e4-46d8-8dd6-57a0beaad69e          retrait       2014-03-11
#
#     status  is_fraud location        amount
# 0  réussie         0     Buea  39328.354516
# 1  réussie         1   Douala  29158.648865
# 2  réussie         0   Garoua  85552.540513
# 3  réussie         1  Yaoundé  79321.951234
# 4  échouée         1   Douala   4289.345369

# %%
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   transaction_id    100000 non-null  object
#  1   customer_id       100000 non-null  object
#  2   device_id         100000 non-null  object
#  3   transaction_type  100000 non-null  object
#  4   transaction_date  100000 non-null  object
#  5   status            100000 non-null  object
#  6   is_fraud          100000 non-null  int64
#  7   location          100000 non-null  object
#  8   amount            100000 non-null  float64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 6.9+ MB

# %%
transactions.describe(include="all")
# Out:
#                           transaction_id                       customer_id  \
# count                             100000                            100000
# unique                            100000                             10000
# top     c97933246a82467a9cfb40ab1d612897  493b54e9a7904f23a78a1b77b89c2ba9
# freq                                   1                                24
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#                                    device_id transaction_type  \
# count                                 100000           100000
# unique                                 63235                3
# top     4387cb60-4d7d-4b7a-ba87-3551bf77cbcc            depôt
# freq                                       8            50052
# mean                                     NaN              NaN
# std                                      NaN              NaN
# min                                      NaN              NaN
# 25%                                      NaN              NaN
# 50%                                      NaN              NaN
# 75%                                      NaN              NaN
# max                                      NaN              NaN
#
#        transaction_date   status       is_fraud location        amount
# count            100000   100000  100000.000000   100000  1.000000e+05
# unique             6938        2            NaN      102           NaN
# top          2013-05-02  réussie            NaN   Douala           NaN
# freq                 31    89877            NaN    11422           NaN
# mean                NaN      NaN       0.339530      NaN  4.467785e+05
# std                 NaN      NaN       0.473552      NaN  1.317093e+06
# min                 NaN      NaN       0.000000      NaN  1.000807e+02
# 25%                 NaN      NaN       0.000000      NaN  3.592390e+04
# 50%                 NaN      NaN       0.000000      NaN  7.152643e+04
# 75%                 NaN      NaN       1.000000      NaN  2.802462e+05
# max                 NaN      NaN       1.000000      NaN  9.996047e+06

# %% [markdown]
# changing date type

# %%
transactions.transaction_date = pd.to_datetime(transactions.transaction_date)
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   transaction_id    100000 non-null  object
#  1   customer_id       100000 non-null  object
#  2   device_id         100000 non-null  object
#  3   transaction_type  100000 non-null  object
#  4   transaction_date  100000 non-null  datetime64[ns]
#  5   status            100000 non-null  object
#  6   is_fraud          100000 non-null  int64
#  7   location          100000 non-null  object
#  8   amount            100000 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(6)
# memory usage: 6.9+ MB

# %% [markdown]
# ### transaction_type

# %%
sns.countplot(transactions, x="transaction_type", hue='transaction_type')
# Out:
# <Axes: xlabel='transaction_type', ylabel='count'>

# %%
transactions.transaction_type.value_counts().sort_values()
# Out:
# transaction_type
# retrait      24905
# transfert    25043
# depôt        50052
# Name: count, dtype: int64

# %%
length = transactions.shape[0]
# create dataframe percentage of transaction type
proportion = pd.DataFrame(transactions['transaction_type'].value_counts(normalize=True)*100)
proportion
# Out:
#                   proportion
# transaction_type
# depôt                 50.052
# transfert             25.043
# retrait               24.905

# %% [markdown]
# ### transaction amount

# %%
# transaction amount by transaction type
pd.DataFrame(transactions.groupby('transaction_type').amount.aggregate(['mean', 'median']))
# Out:
#                            mean        median
# transaction_type
# depôt             445528.337214  71802.280615
# retrait           451907.168382  71698.048334
# transfert         444176.541737  70799.786992

# %%
transfert = transactions[transactions.transaction_type == 'transfert']
depot = transactions[transactions.transaction_type == 'depôt']
retrait = transactions[transactions.transaction_type == 'retrait']
type_list = [transfert, depot, retrait]

# %%
sns.histplot(transactions, x="amount", kde=True)
# Out:
# <Axes: xlabel='amount', ylabel='Count'>

# %%
plt.figure(figsize=(15,7))
for i, value in enumerate(type_list, 1):
    plt.subplot(2,2,i)
    sns.histplot(value, x='amount', kde=True)
    plt.title(value.transaction_type.iloc[0])
    plt.tight_layout()
    plt.plot()

# %%
plt.figure(figsize=(15,4))
for i, value in enumerate(type_list, 1):
    plt.subplot(2,2,i)
    sns.boxplot(value, x='amount')
    plt.title(value.transaction_type.iloc[0])
    plt.tight_layout()
    plt.plot()

# %% [markdown]
# ### Analyse temporelle

# %%
transactions['month'] = pd.to_datetime(transactions['transaction_date'].dt.strftime('%Y-%m'))
transactions['week'] = transactions['transaction_date'].dt.isocalendar().week
transactions['month_number'] = transactions['transaction_date'].dt.month
transactions['year'] = transactions['transaction_date'].dt.year

# %%
transactions_copy = transactions.set_index('transaction_date')
transactions_copy.head()
# Out:
#                                     transaction_id  \
# transaction_date
# 2005-08-23        c97933246a82467a9cfb40ab1d612897
# 2005-03-31        93fbfd13f9b34e0d9820b8731340aa40
# 2011-12-17        2ae38ab84eec4dad879cc457ffe0c954
# 2014-03-10        fa94fac99017496b9c8139c474a9b1da
# 2014-03-11        8bbb805c101b420793a3b51b22766613
#
#                                        customer_id  \
# transaction_date
# 2005-08-23        bfac7b9b0f9c4c2b92124cf5f9bac2c2
# 2005-03-31        e7506952844a4d38be9379d7580e4c25
# 2011-12-17        913098ce3c834dbbb199ebdf11ac1955
# 2014-03-10        42b6a8b5a41845ceaa50554faaa9610b
# 2014-03-11        5d5cc9db27534a6aaa5434114c6b6c3a
#
#                                              device_id transaction_type  \
# transaction_date
# 2005-08-23        c2e3ea31-d1a5-4d65-a9f8-8b3b733a33b4        transfert
# 2005-03-31        2beb8b14-8655-4b71-a925-ef4ba64b2295          retrait
# 2011-12-17        ef66fa7d-0f58-43dd-aa29-aa9af742a86c        transfert
# 2014-03-10        d676bb76-3798-49d9-83c6-a7d8d20c4302            depôt
# 2014-03-11        e8a74deb-98e4-46d8-8dd6-57a0beaad69e          retrait
#
#                    status  is_fraud location        amount      month  week  \
# transaction_date
# 2005-08-23        réussie         0     Buea  39328.354516 2005-08-01    34
# 2005-03-31        réussie         1   Douala  29158.648865 2005-03-01    13
# 2011-12-17        réussie         0   Garoua  85552.540513 2011-12-01    50
# 2014-03-10        réussie         1  Yaoundé  79321.951234 2014-03-01    11
# 2014-03-11        échouée         1   Douala   4289.345369 2014-03-01    11
#
#                   month_number  year
# transaction_date
# 2005-08-23                   8  2005
# 2005-03-31                   3  2005
# 2011-12-17                  12  2011
# 2014-03-10                   3  2014
# 2014-03-11                   3  2014

# %% [markdown]
# Montant de transaction par jour

# %%
transactions_per_day = pd.DataFrame(transactions_copy.groupby('transaction_date').amount.aggregate("mean")).reset_index()
fig = px.line(transactions_per_day, x='transaction_date', y='amount', title='transactions_per_day amount')

fig.update_xaxes(rangeslider_visible=True)
fig.show()

# %% [markdown]
# Montant de transaction par mois

# %%
transactions_per_month = pd.DataFrame(transactions_copy.groupby("month").amount.aggregate('mean')).reset_index()
fig = px.line(transactions_per_month, x='month', y='amount', title='transactions_per_month amount')

fig.update_xaxes(rangeslider_visible=True)
fig.show()

# %% [markdown]
# Montant de transaction par an

# %%
transactions_per_month = pd.DataFrame(transactions_copy.groupby("year").amount.aggregate('mean')).reset_index()
fig = px.line(transactions_per_month, x='year', y='amount', title='transactions_per_month amount')

fig.update_xaxes(rangeslider_visible=True)
fig.show()

# %% [markdown]
# Nombre de transaction par jour

# %%
transactions_per_day_nbr = pd.DataFrame(transactions_copy.groupby("transaction_date").transaction_id.count()).reset_index()
fig = px.line(transactions_per_day_nbr, x='transaction_date', y='transaction_id', title='transactions_per_day_nbr')

fig.update_xaxes(rangeslider_visible=True)
fig.show()

# %% [markdown]
# Nombre de transaction par mois

# %%
transactions_per_month_nbr = pd.DataFrame(transactions_copy.groupby("month").transaction_id.count()).reset_index()
fig = px.line(transactions_per_month_nbr, x='month', y='transaction_id', title='transactions_per_month_nbr')

fig.update_xaxes(rangeslider_visible=True)
fig.show()

# %% [markdown]
# Nombre de transaction par an

# %%
transactions_per_month_nbr = pd.DataFrame(transactions_copy.groupby("year").transaction_id.count()).reset_index()
fig = px.line(transactions_per_month_nbr, x='year', y='transaction_id', title='transactions_per_month_nbr')

fig.update_xaxes(rangeslider_visible=True)
